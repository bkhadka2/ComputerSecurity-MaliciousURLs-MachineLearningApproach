# %%
import pandas as pd
import numpy as np
print('import complete')
# Out:
# import complete

# %%
df = pd.read_csv('Cleaned_Data.csv')
# Out:
# /home/bishal/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0  Querylength  domain_token_count  path_token_count  \
# 0           0            0                   4                 5
# 1           1            0                   4                 5
# 2           2            0                   4                 5
# 3           3            0                   4                12
# 4           4            0                   4                 6
#
#    avgdomaintokenlen  longdomaintokenlen  tld  charcompvowels  charcompace  \
# 0                5.5                  14    4               8            3
# 1                5.5                  14    4              12            4
# 2                5.5                  14    4              12            5
# 3                5.5                  14    4              32           16
# 4                5.5                  14    4              18           11
#
#    ldl_url  ...  NumberRate_Domain  SymbolCount_URL  SymbolCount_Domain  \
# ...

# %%
del df['Unnamed: 0']

# %%
df.head()
# Out:
#    Querylength  domain_token_count  path_token_count  avgdomaintokenlen  \
# 0            0                   4                 5                5.5
# 1            0                   4                 5                5.5
# 2            0                   4                 5                5.5
# 3            0                   4                12                5.5
# 4            0                   4                 6                5.5
#
#    longdomaintokenlen  tld  charcompvowels  charcompace  ldl_url  ldl_domain  \
# 0                  14    4               8            3        0           0
# 1                  14    4              12            4        0           0
# 2                  14    4              12            5        0           0
# 3                  14    4              32           16        0           0
# 4                  14    4              18           11        0           0
#
#    ...  NumberRate_Domain  SymbolCount_URL  SymbolCount_Domain  \
# ...

# %%
selectedFeatures = ['pathLength', 'subDirLen', 'charcompvowels', 'ldl_path', 'ldl_url', 'URL_sensitiveWord', 'isPortEighty', 'charcompace', 'dld_domain', 'NumberRate_Domain', 'URL_Type_obf_Type']

# %%
for mem in df.columns:
    if mem not in selectedFeatures:
        del df[mem]

# %%
df.head()
# Out:
#    charcompvowels  charcompace  ldl_url  ldl_path  dld_domain  pathLength  \
# 0               8            3        0         0           0          26
# 1              12            4        0         0           0          34
# 2              12            5        0         0           0          33
# 3              32           16        0         0           0          77
# 4              18           11        0         0           0          49
#
#    subDirLen  isPortEighty  URL_sensitiveWord  NumberRate_Domain  \
# 0         26            -1                  0                0.0
# 1         34            -1                  0                0.0
# 2         33            -1                  0                0.0
# 3         77            -1                  0                0.0
# 4         49            -1                  0                0.0
#
#   URL_Type_obf_Type
# 0        Defacement
# 1        Defacement
# 2        Defacement
# 3        Defacement
# 4        Defacement

# %%
charcompvowelsList = df['charcompvowels']
charcompaceList = df['charcompace']
ldl_urlList = df['ldl_url']
ldl_pathList = df['ldl_path']
dld_domainList = df['dld_domain']
pathLengthList = df['pathLength']
subDirLenList = df['subDirLen']
isPortEightyList = df['isPortEighty']
URL_sensitiveWordList = df['URL_sensitiveWord']
NumberRate_DomainList = df['NumberRate_Domain']

# %%
combinedList = list(zip(charcompvowelsList, charcompaceList, ldl_urlList, ldl_pathList, dld_domainList, pathLengthList, subDirLenList, isPortEightyList, URL_sensitiveWordList, NumberRate_DomainList))

# %%
df['URL_Type_obf_Type'] = df['URL_Type_obf_Type'].map(lambda val : 0 if val == 'benign' else 1)

# %%
df.head()
# Out:
#    charcompvowels  charcompace  ldl_url  ldl_path  dld_domain  pathLength  \
# 0               8            3        0         0           0          26
# 1              12            4        0         0           0          34
# 2              12            5        0         0           0          33
# 3              32           16        0         0           0          77
# 4              18           11        0         0           0          49
#
#    subDirLen  isPortEighty  URL_sensitiveWord  NumberRate_Domain  \
# 0         26            -1                  0                0.0
# 1         34            -1                  0                0.0
# 2         33            -1                  0                0.0
# 3         77            -1                  0                0.0
# 4         49            -1                  0                0.0
#
#    URL_Type_obf_Type
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# ...

# %%
target_value = list()

# %%
for mem in df['URL_Type_obf_Type']:
    target_value.append(mem)

# %%
from sklearn.model_selection import train_test_split

# %%
random_state = 1
X = combinedList
y = target_value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=random_state, stratify=y)

# %%
print("Number of training samples: {}".format(len(X_train)))
print("Number of testing samples: {}".format(len(X_test)))
# Out:
# Number of training samples: 29365
# Number of testing samples: 7342

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
randomForest = RandomForestClassifier(max_depth=2, random_state=random_state)
decisionTree = DecisionTreeClassifier(random_state = random_state)

# %%
randomForest.fit(X_train, y_train)
print("Random Forest fitted")
decisionTree.fit(X_train, y_train)
print("Decision Tree fitted")
# Out:
# /home/bishal/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Random Forest fitted
# Decision Tree fitted

# %%
randomForestResult = randomForest.score(X_test, y_test)
decisionTreeResult = decisionTree.score(X_test, y_test)

print('Random Forest: {:.2f}'.format(randomForestResult))
print('Decision Tree: {:.2f}'.format(decisionTreeResult))
# Out:
# Random Forest: 0.79
# Decision Tree: 0.86
